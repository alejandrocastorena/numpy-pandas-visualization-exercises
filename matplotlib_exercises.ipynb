# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
print(plt)
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/anaconda3/lib/python3.10/site-packages/matplotlib/pyplot.py'>

# %%
# Use matplotlib to plot the following equation:
# y= x2−x+2

# %%
x = range(0,50)
y = [x*x-x+2 for x in x]

plt.plot(x, c='green')
plt.annotate('origin', xy=(0,0),
            arrowprops={'facecolor': 'yellow'})
plt.show()

# %%
# Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
y=√x
y=x3
y=2x
y=1/(x+1)

# %%
x = range(0,50)
y = [x*x for x in x]

plt.plot(x,y)

# %%
x = range(0,50)
y = [x*x*x for x in x]

plt.plot(x,y)

# %%
x = range(0,50)
y = [2**x for x in x]

plt.plot(x,y)

# %%
x = range(0,50)
y = [1/(x+1) for x in x]

plt.plot(x,y)

# %%
# Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
x = range(0,10)
y1 = [x*x for x in x]
y2 = [x*x*x for x in x]
y3 = [2**x for x in x]
y4 = y = [1/(x+1) for x in x]

# %%
plt.figure(figsize = (10,6))

plt.plot(x, y1, color = 'red', ls = '--', marker = '^', label = 'y1')
plt.plot(x, y2, color = 'black', ls = ':', marker = 'o', label = 'y2')
plt.plot(x, y3, color = 'blue', ls = '--', marker = 'v', label = 'y3')
plt.plot(x, y4, color = 'green', ls = ':', marker = '.', label = 'y4')

plt.legend(loc='upper right')
plt.title('random')
plt.xlabel('$x$')
plt.ylabel('$y$')

plt.xlim(0,8)
plt.ylim(0,30)
plt.show()
